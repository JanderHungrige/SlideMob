# %%
import os
import dotenv
dotenv.load_dotenv()
from typing import List, Tuple


#pptx transformation imports
import zipfile
import shutil
import warnings

#spellcheck imports
import xml.etree.ElementTree as ET
import re

# translator import
import xml.etree.ElementTree as ET
from openai import OpenAI
from pydantic import BaseModel
import json

# %%
def extract_pptx(pptx_path: str, extract_path: str) -> str:
    """Extract a PPTX file into its XML components."""
    os.makedirs(extract_path, exist_ok=True)
    
    with zipfile.ZipFile(pptx_path, 'r') as pptx:
        pptx.extractall(extract_path)
    
    # Get namespaces right after extraction
    return extract_path


def compose_pptx(self, source_path: str, output_pptx: str):
    """Compose a PPTX file from a directory containing the XML structure."""
    os.makedirs(os.path.dirname(output_pptx), exist_ok=True)
    
    with zipfile.ZipFile(output_pptx, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
        for root, _, files in os.walk(source_path):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, source_path)
                zf.write(file_path, arcname)

# %%
def extract_paragraph_elements_with_attributes(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    default_namespace = {
        'a': 'http://schemas.openxmlformats.org/drawingml/2006/main',
        'r': 'http://schemas.openxmlformats.org/officeDocument/2006/relationships',
        'p': 'http://schemas.openxmlformats.org/presentationml/2006/main',   
    }
    paragraphs = root.findall('.//a:p', default_namespace)
    all_paragraphs = []
    
    for paragraph in paragraphs:
        paragraph_data = {
            "paragraph_attributes": paragraph.attrib,
            "paragraph_properties": paragraph.find('.//a:pPr', default_namespace).attrib if paragraph.find('.//a:pPr', default_namespace) is not None else {},
            "runs": [],
            "full_text": "",
            "text_elements": []
        }
        
        # Look for runs within the paragraph
        runs = paragraph.findall('.//a:r', default_namespace)
        paragraph_text = []
        
        for run in runs:
            text_elements = run.findall('.//a:t', default_namespace)
            run_texts = [elem.text if elem is not None and elem.text is not None else "" for elem in text_elements]
            
            run_data = {
                "run_attributes": run.attrib,
                "run_properties": run.find('.//a:rPr', default_namespace).attrib if run.find('.//a:rPr', default_namespace) is not None else {},
                "text": run_texts,
                "text_as_string": f"[{' '.join(run_texts)}]"
            }
            paragraph_data["runs"].append(run_data)
            paragraph_text.extend(run_texts)
            paragraph_data["text_elements"].extend(run_texts)
        
        # Combine all text from the paragraph
        paragraph_data["full_text"] = " ".join(paragraph_text)
        all_paragraphs.append(paragraph_data)
    
    return all_paragraphs

# %%
def find_slide_files(root_folder: str) -> List[str]:
            """Find all slide XML files in the folder structure."""
            slide_files = []
            for root, _, files in os.walk(root_folder):
                for file in files:
                    if file.startswith('slide') and file.endswith('.xml'):
                        number_part = file[5:-4]
                        if number_part.isdigit():
                            slide_files.append(os.path.join(root, file))
            return sorted(slide_files)

def extract_paragraphs(xml_file: str, namespaces: dict) -> List[ET.Element]:
    """Extract everything inside paragraphs from the XML file."""
    tree = ET.parse(xml_file)
    root = tree.getroot()
    return root.findall('.//a:p', namespaces)

#function to extract attributes from paragraph elements into readable text
def extract_information_from_paragraphs(paragraphs: List[ET.Element]):
    for paragraph in paragraphs:
        print(paragraph.attrib)

# %%
if __name__ == "__main__":
    root_folder = "/Users/jwh/Code/Translator"
    pptx_name = "2024-10-23_ASML_Regulation_and_Governance_GenAI.pptx"
    openai_api_key = os.getenv("OPENAI_API_KEY")
    namespaces: dict={'a': 'http://schemas.openxmlformats.org/drawingml/2006/main'}

    extract_pptx(root_folder+"/"+pptx_name, root_folder+"/extracted_pptx")
    slide_files = find_slide_files(root_folder+"/extracted_pptx")
  # Usage
    xml_file = slide_files[2]
    paragraphs_data = extract_paragraph_elements_with_attributes(xml_file)
    for i, paragraph in enumerate(paragraphs_data, start=1):
        print(f"\nParagraph {i}:")
        print(f"Paragraph Attributes: {paragraph['paragraph_attributes']}")
        print(f"Paragraph Properties: {paragraph['paragraph_properties']}")
        print(f"Full Text: {paragraph['full_text']}")
        print(f"Individual Text Elements: {paragraph['text_elements']}")  # New print statement

        print("\nRuns in this paragraph:")
        for j, run in enumerate(paragraph['runs'], start=1):
            print(f"\n  Run {j}:")
            print(f"    Run Attributes: {run['run_attributes']}")
            print(f"    Run Properties: {run['run_properties']}")
            print(f"    Text Content: {run['text']}")
        print("\n" + "-"*50)
# Out:
# Paragraph 1:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 2:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 3:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Regulatory, …
# Individual Text Elements: ['Regulatory, … ']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Regulatory, … ']
#
# --------------------------------------------------
#
# Paragraph 4:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text:  documents
# Individual Text Elements: [' documents']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: [' documents']
#
# --------------------------------------------------
#
# Paragraph 5:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 6:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 7:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 8:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 9:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 10:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 11:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 12:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 13:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 14:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 15:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 16:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 17:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Project data
# Individual Text Elements: ['Project data ']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Project data ']
#
# --------------------------------------------------
#
# Paragraph 18:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 19:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 20:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 21:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 22:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 23:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 24:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Critical documents
# Individual Text Elements: ['Critical documents']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Critical documents']
#
# --------------------------------------------------
#
# Paragraph 25:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 26:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 27:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Standard
# Individual Text Elements: ['Standard ']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Standard ']
#
# --------------------------------------------------
#
# Paragraph 28:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: documents
# Individual Text Elements: ['documents']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['documents']
#
# --------------------------------------------------
#
# Paragraph 29:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 30:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: GenAI
# Individual Text Elements: ['GenAI']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900', 'err': '1'}
#     Text Content: ['GenAI']
#
# --------------------------------------------------
#
# Paragraph 31:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 32:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 33:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Project  documents
# Individual Text Elements: ['Project', ' documents']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Project']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: [' documents']
#
# --------------------------------------------------
#
# Paragraph 34:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 35:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Expert
# Individual Text Elements: ['Expert']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Expert']
#
# --------------------------------------------------
#
# Paragraph 36:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text:  check
# Individual Text Elements: [' check']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: [' check']
#
# --------------------------------------------------
#
# Paragraph 37:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 38:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 39:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Document
# Individual Text Elements: ['Document ']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Document ']
#
# --------------------------------------------------
#
# Paragraph 40:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: adaption
# Individual Text Elements: ['adaption']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['adaption']
#
# --------------------------------------------------
#
# Paragraph 41:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 42:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'ctr'}
# Full Text: Quick  check
# Individual Text Elements: ['Quick ', 'check']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['Quick ']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '900'}
#     Text Content: ['check']
#
# --------------------------------------------------
#
# Paragraph 43:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 44:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 45:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text: 10%
# Individual Text Elements: ['10%']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['10%']
#
# --------------------------------------------------
#
# Paragraph 46:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text: 90%
# Individual Text Elements: ['90%']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['90%']
#
# --------------------------------------------------
#
# Paragraph 47:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 48:
# Paragraph Attributes: {}
# Paragraph Properties: {}
# Full Text: Expert AI-assistance
# Individual Text Elements: ['Expert AI-assistance']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB'}
#     Text Content: ['Expert AI-assistance']
#
# --------------------------------------------------
#
# Paragraph 49:
# Paragraph Attributes: {}
# Paragraph Properties: {}
# Full Text: Reducing the manual workload by using AI to  pinpoint the critical documents
# Individual Text Elements: ['Reducing the manual workload by using AI to ', 'pinpoint the critical documents']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'b': '0'}
#     Text Content: ['Reducing the manual workload by using AI to ']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB'}
#     Text Content: ['pinpoint the critical documents']
#
# --------------------------------------------------
#
# Paragraph 50:
# Paragraph Attributes: {}
# Paragraph Properties: {}
# Full Text: AI can support with information gathering and processing as well as with risk and impact assessment.
# Individual Text Elements: ['AI can support with information gathering and processing as well as with risk and impact assessment.']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['AI can support with information gathering and processing as well as with risk and impact assessment.']
#
# --------------------------------------------------
#
# Paragraph 51:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 52:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text: Experts only need to manually review a small fraction of cases  (here e.g., 10%), allowing them to focus on the most critical ones.
# Individual Text Elements: ['Experts only need to manually review a small fraction of cases ', '(here e.g., 10%), allowing them to focus on the most critical ones.']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200', 'b': '1'}
#     Text Content: ['Experts only need to manually review a small fraction of cases ']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['(here e.g., 10%), allowing them to focus on the most critical ones.']
#
# --------------------------------------------------
#
# Paragraph 53:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text: Regulations, requirements, laws,  etc.  must be checked by experts  to make informed decisions.
# Individual Text Elements: ['Regulations, requirements, laws, ', 'etc. ', 'must be checked by experts ', 'to make informed decisions. ']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200', 'b': '1'}
#     Text Content: ['Regulations, requirements, laws, ']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['etc. ']
#
#   Run 3:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200', 'b': '1'}
#     Text Content: ['must be checked by experts ']
#
#   Run 4:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['to make informed decisions. ']
#
# --------------------------------------------------
#
# Paragraph 54:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text: This will not be eliminated by AI. However, we can  reduce the amount of information to be screened .
# Individual Text Elements: ['This will not be eliminated by AI. However, we can ', 'reduce the amount of information to be screened', '. ']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['This will not be eliminated by AI. However, we can ']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200', 'b': '1'}
#     Text Content: ['reduce the amount of information to be screened']
#
#   Run 3:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['. ']
#
# --------------------------------------------------
#
# Paragraph 55:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 56:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text: Highlighting, preprocessing, and presenting important information and their interdependencies  boosts the information gathering  and decision-making process.
# Individual Text Elements: ['Highlighting, preprocessing, and presenting important information and their interdependencies ', 'boosts the information gathering', ' and decision-making process.']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['Highlighting, preprocessing, and presenting important information and their interdependencies ']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200', 'b': '1'}
#     Text Content: ['boosts the information gathering']
#
#   Run 3:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: [' and decision-making process.']
#
# --------------------------------------------------
#
# Paragraph 57:
# Paragraph Attributes: {}
# Paragraph Properties: {'algn': 'l'}
# Full Text:
# Individual Text Elements: []
#
# Runs in this paragraph:
#
# --------------------------------------------------
#
# Paragraph 58:
# Paragraph Attributes: {}
# Paragraph Properties: {}
# Full Text: This reduces time and costs; and it allows  experts to focus  on more complex and strategic activities that require critical thinking and creativity.
# Individual Text Elements: ['This reduces time and costs; and it allows ', 'experts to focus ', 'on more complex and strategic activities that require critical thinking and creativity.']
#
# Runs in this paragraph:
#
#   Run 1:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['This reduces time and costs; and it allows ']
#
#   Run 2:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200', 'b': '1'}
#     Text Content: ['experts to focus ']
#
#   Run 3:
#     Run Attributes: {}
#     Run Properties: {'lang': 'en-GB', 'sz': '1200'}
#     Text Content: ['on more complex and strategic activities that require critical thinking and creativity.']
#
# --------------------------------------------------
